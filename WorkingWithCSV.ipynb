# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitsrm/MachineLearning/blob/main/WorkingWithCSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# Import data csv file from URL

# %%
import requests
from io import StringIO
url="https://github.com/campusx-official/100-days-of-machine-learning/blob/main/day15%20-%20working%20with%20csv%20files/aug_train.csv"
headers={"User-Agent":"Mozilla/5.0(Macintosh;Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO (req.text)
df = pd.read_csv(data)
df

# %% [markdown]
# Import data from TSV File
#
# --------------------------
# In this value is seperated with tab. So read_csv method by default sep with ,
# ko pretend karta hai
# but in tsv its not sep with , it is with tab

# %%
df = pd.read_csv('movie_titles_metadata.tsv')
df
# Out:
#     m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0    m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1    m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2    m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3    m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4    m5\tthe fifth element\t1997\t7.50\t133756\t['a...
# ..                                                 ...
# 611  m612\twatchmen\t2009\t7.80\t135229\t['action' ...
# 612  m613\txxx\t2002\t5.60\t53505\t['action' 'adven...
# 613  m614\tx-men\t2000\t7.40\t122149\t['action' 'sc...
# 614  m615\tyoung frankenstein\t1974\t8.00\t57618\t[...
# 615  m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
#
# [616 rows x 1 columns]

# %%
df = pd.read_csv("movie_titles_metadata.tsv", sep='\t')

# %%
df
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %%
df = pd.read_csv("movie_titles_metadata.tsv",sep="\t",names=["sno","moviename","year","rating","votes","geners"])

# %%
df
# Out:
#       sno                   moviename  year  rating     votes  \
# 0      m0  10 things i hate about you  1999     6.9   62847.0
# 1      m1  1492: conquest of paradise  1992     6.2   10421.0
# 2      m2                  15 minutes  2001     6.1   25854.0
# 3      m3       2001: a space odyssey  1968     8.4  163227.0
# 4      m4                     48 hrs.  1982     6.9   22289.0
# ..    ...                         ...   ...     ...       ...
# 612  m612                    watchmen  2009     7.8  135229.0
# 613  m613                         xxx  2002     5.6   53505.0
# 614  m614                       x-men  2000     7.4  122149.0
# 615  m615          young frankenstein  1974     8.0   57618.0
# 616  m616                   zulu dawn  1979     6.4    1911.0
#
#                                                 geners
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# ...

# %% [markdown]
# # Index_Col Parameter

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hear we have 2 ids one is srno 0,1,2 another is enrollee_id, If we want to keep one index then we can remove it

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv', index_col="longitude")
df
# Out:
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.05       37.37                27.0       3885.0           661.0
# -118.30       34.26                43.0       1510.0           310.0
# -117.81       33.78                27.0       3589.0           507.0
# -118.36       33.82                28.0         67.0            15.0
# -119.67       36.33                19.0       1241.0           244.0
# ...             ...                 ...          ...             ...
# -119.86       34.42                23.0       1450.0           642.0
# -118.14       34.06                27.0       5257.0          1082.0
# -119.70       36.30                10.0        956.0           201.0
# -117.12       34.10                40.0         96.0            14.0
# -119.63       34.42                42.0       1765.0           263.0
#
#            population  households  median_income  median_house_value
# longitude
# ...

# %% [markdown]
# # Header Parameter
#
# first row jo hai wo column ka name hai but some time wo column ka name as row hojata hai then to fix this

# %%
df = pd.read_csv("test.csv")
df
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
df = pd.read_csv("test.csv",header=1)

# %%
df
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# # Use Cols Parameter
#
# where we dont want some column and it will remove the colum and provide as we need

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv', usecols=['population','households','median_income'])
# Out:
#       population  households  median_income
# 0         1537.0       606.0         6.6085
# 1          809.0       277.0         3.5990
# 2         1484.0       495.0         5.7934
# 3           49.0        11.0         6.1359
# 4          850.0       237.0         2.9375
# ...          ...         ...            ...
# 2995      1258.0       607.0         1.1790
# 2996      3496.0      1036.0         3.3906
# 2997       693.0       220.0         2.2895
# 2998        46.0        14.0         3.2708
# 2999       753.0       260.0         8.5608
#
# [3000 rows x 3 columns]

# %% [markdown]
# # Squeeze parameters
#
# Sometime we need one column --- so ye pandas dataframe na bane ke pandas series ban jata hai

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv', usecols=['population'], squeeze= True)
# Out:
# <ipython-input-25-f4b53403d306>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pd.read_csv('/content/sample_data/california_housing_test.csv', usecols=['population'], squeeze= True)
# 0       1537.0
# 1        809.0
# 2       1484.0
# 3         49.0
# 4        850.0
#          ...
# 2995    1258.0
# 2996    3496.0
# 2997     693.0
# 2998      46.0
# 2999     753.0
# Name: population, Length: 3000, dtype: float64

# %% [markdown]
# # Skip Rows and Nrows Parameter

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv', skiprows=[0,1])
# Out:
#       -118.300000  34.260000  43.000000  1510.000000  310.000000  809.000000  \
# 0         -117.81      33.78       27.0       3589.0       507.0      1484.0
# 1         -118.36      33.82       28.0         67.0        15.0        49.0
# 2         -119.67      36.33       19.0       1241.0       244.0       850.0
# 3         -119.56      36.51       37.0       1018.0       213.0       663.0
# 4         -121.43      38.63       43.0       1009.0       225.0       604.0
# ...           ...        ...        ...          ...         ...         ...
# 2993      -119.86      34.42       23.0       1450.0       642.0      1258.0
# 2994      -118.14      34.06       27.0       5257.0      1082.0      3496.0
# 2995      -119.70      36.30       10.0        956.0       201.0       693.0
# 2996      -117.12      34.10       40.0         96.0        14.0        46.0
# 2997      -119.63      34.42       42.0       1765.0       263.0       753.0
#
#       277.000000  3.599000  176500.000000
# ...

# %% [markdown]
# Nrows -- Get limited rows only

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv', nrows=100)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.05     37.37                27.0       3885.0           661.0
# 1     -118.30     34.26                43.0       1510.0           310.0
# 2     -117.81     33.78                27.0       3589.0           507.0
# 3     -118.36     33.82                28.0         67.0            15.0
# 4     -119.67     36.33                19.0       1241.0           244.0
# ..        ...       ...                 ...          ...             ...
# 95    -119.82     36.64                30.0       1694.0           312.0
# 96    -120.21     36.77                20.0       1745.0           348.0
# 97    -120.97     38.42                16.0       1748.0           322.0
# 98    -121.19     38.87                20.0       3118.0           500.0
# 99    -118.20     33.77                52.0       1375.0           457.0
#
#     population  households  median_income  median_house_value
# ...

# %% [markdown]
# ## 10.Encoding parameter

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Skit Bad Lines

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv', nrows=100).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           100 non-null    float64
#  1   latitude            100 non-null    float64
#  2   housing_median_age  100 non-null    float64
#  3   total_rooms         100 non-null    float64
#  4   total_bedrooms      100 non-null    float64
#  5   population          100 non-null    float64
#  6   households          100 non-null    float64
#  7   median_income       100 non-null    float64
#  8   median_house_value  100 non-null    float64
# dtypes: float64(9)
# memory usage: 7.2 KB

# %% [markdown]
# ### Change Data Type dtype

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv', nrows=100)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.05     37.37                27.0       3885.0           661.0
# 1     -118.30     34.26                43.0       1510.0           310.0
# 2     -117.81     33.78                27.0       3589.0           507.0
# 3     -118.36     33.82                28.0         67.0            15.0
# 4     -119.67     36.33                19.0       1241.0           244.0
# ..        ...       ...                 ...          ...             ...
# 95    -119.82     36.64                30.0       1694.0           312.0
# 96    -120.21     36.77                20.0       1745.0           348.0
# 97    -120.97     38.42                16.0       1748.0           322.0
# 98    -121.19     38.87                20.0       3118.0           500.0
# 99    -118.20     33.77                52.0       1375.0           457.0
#
#     population  households  median_income  median_house_value
# ...

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv', nrows=100, dtype={'housing_median_age':int})
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.05     37.37                  27       3885.0           661.0
# 1     -118.30     34.26                  43       1510.0           310.0
# 2     -117.81     33.78                  27       3589.0           507.0
# 3     -118.36     33.82                  28         67.0            15.0
# 4     -119.67     36.33                  19       1241.0           244.0
# ..        ...       ...                 ...          ...             ...
# 95    -119.82     36.64                  30       1694.0           312.0
# 96    -120.21     36.77                  20       1745.0           348.0
# 97    -120.97     38.42                  16       1748.0           322.0
# 98    -121.19     38.87                  20       3118.0           500.0
# 99    -118.20     33.77                  52       1375.0           457.0
#
#     population  households  median_income  median_house_value
# ...

# %% [markdown]
# # Handling Dates

# %% [markdown]
# By default date wale column get change it into string which cause issue

# %%
df = pd.read_csv("movie_titles_metadata.tsv",sep="\t",names=["sno","moviename","year","rating","votes","geners"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sno        617 non-null    object
#  1   moviename  616 non-null    object
#  2   year       616 non-null    object
#  3   rating     616 non-null    float64
#  4   votes      616 non-null    float64
#  5   geners     616 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 29.0+ KB

# %%
df = pd.read_csv("movie_titles_metadata.tsv",sep="\t",names=["sno","moviename","year","rating","votes","geners"], parse_dates=['year']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sno        617 non-null    object
#  1   moviename  616 non-null    object
#  2   year       616 non-null    object
#  3   rating     616 non-null    float64
#  4   votes      616 non-null    float64
#  5   geners     616 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 29.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sno        617 non-null    object
#  1   moviename  616 non-null    object
#  2   year       616 non-null    object
#  3   rating     616 non-null    float64
#  4   votes      616 non-null    float64
#  5   geners     616 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 29.0+ KB

# %% [markdown]
# # Converters
#
# We want to do some transformation

# %%
pd.read_csv("IPL Matches 2008-2020.csv")
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
pd.read_csv("IPL Matches 2008-2020.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df = pd.read_csv("IPL Matches 2008-2020.csv",parse_dates=['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
import pandas as pd
pd.read_csv("IPL Matches 2008-2020.csv")
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# ## COnverters

# %%
def rename(name):
  if name == "Royal Challengers Bangalore":
    return "RCB"
  else:
       return name

# %%
df = pd.read_csv("IPL Matches 2008-2020.csv",converters = {'team1': rename})

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # Na_values Parameter

# %% [markdown]
# This is that some value which isnt helpfull like - or , or < or that to edit it out Nan

# %%
pd.read_csv('IPL Matches 2008-2020.csv', na_values=['bat'])
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # **Loading a huge dataset in chunks**

# %% [markdown]
# Hear i want to make a break the huge data set in chunks

# %%
dff = pd.read_csv("IPL Matches 2008-2020.csv", chunksize=50)

# %%
for chunks in dff:
  print(chunks.size)
